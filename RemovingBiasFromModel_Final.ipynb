# %%
# !pip install scikit-learn-intelex
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Collecting scikit-learn-intelex
#   Downloading scikit_learn_intelex-2023.2.1-py310-none-manylinux1_x86_64.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 1.4 MB/s eta 0:00:00
# Collecting daal4py==2023.2.1 (from scikit-learn-intelex)
#   Downloading daal4py-2023.2.1-py310-none-manylinux1_x86_64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 45.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-intelex) (1.2.2)
# Collecting daal==2023.2.1 (from daal4py==2023.2.1->scikit-learn-intelex)
#   Downloading daal-2023.2.1-py2.py3-none-manylinux1_x86_64.whl (75.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 MB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from daal4py==2023.2.1->scikit-learn-intelex) (1.23.5)
# Requirement already satisfied: tbb==2021.* in /usr/local/lib/python3.10/dist-packages (from daal==2023.2.1->daal4py==2023.2.1->scikit-learn-intelex) (2021.10.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (3.2.0)
# Installing collected packages: daal, daal4py, scikit-learn-intelex
# Successfully installed daal-2023.2.1 daal4py-2023.2.1 scikit-learn-intelex-2023.2.1
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
# !pip install fairlearn
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
import keras.backend as K
from tensorflow.keras.layers import Lambda
from fairlearn.metrics import demographic_parity_difference
from fairlearn.metrics import equalized_odds_ratio
from fairlearn.metrics import equalized_odds_difference
import numpy as np
# Out:
# Collecting fairlearn
#   Downloading fairlearn-0.9.0-py3-none-any.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.5/231.5 kB 998.6 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from fairlearn) (1.23.5)
# Requirement already satisfied: pandas>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from fairlearn) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.10/dist-packages (from fairlearn) (1.2.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from fairlearn) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.2->fairlearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.2->fairlearn) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.1->fairlearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.1->fairlearn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25.2->fairlearn) (1.16.0)
# Installing collected packages: fairlearn
# Successfully installed fairlearn-0.9.0

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.1)

# %%
# !wget https://archive.ics.uci.edu/static/public/2/adult.zip
# !unzip adult.zip
# Out:
# --2023-09-06 11:18:44--  https://archive.ics.uci.edu/static/public/2/adult.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘adult.zip’
#
# adult.zip               [  <=>               ] 605.70K  1.57MB/s    in 0.4s
#
# 2023-09-06 11:18:45 (1.57 MB/s) - ‘adult.zip’ saved [620237]
#
# Archive:  adult.zip
#   inflating: Index
#   inflating: adult.data
#   inflating: adult.names
#   inflating: adult.test
#   inflating: old.adult.names

# %%
cols="age	workclass	fnlwgt	education	educational-num	marital-status	occupation	relationship	race	gender	capital-gain	capital-loss	hours-per-week	native-country	income"
cols=cols.split("\t")

# %%
#Run this cell if using it locally
# %cd Downloads/
# Out:
# [Errno 2] No such file or directory: 'Downloads/'
# /Users/e151276/Downloads

# %%
train=pd.read_csv("adult.data",names=cols)
test=pd.read_csv("adult.test",skiprows=1,names=cols)
train.reset_index()
test.reset_index()
# Out:
#        index  age      workclass  fnlwgt      education  educational-num  \
# 0          0   25        Private  226802           11th                7
# 1          1   38        Private   89814        HS-grad                9
# 2          2   28      Local-gov  336951     Assoc-acdm               12
# 3          3   44        Private  160323   Some-college               10
# 4          4   18              ?  103497   Some-college               10
# ...      ...  ...            ...     ...            ...              ...
# 16276  16276   39        Private  215419      Bachelors               13
# 16277  16277   64              ?  321403        HS-grad                9
# 16278  16278   38        Private  374983      Bachelors               13
# 16279  16279   44        Private   83891      Bachelors               13
# 16280  16280   35   Self-emp-inc  182148      Bachelors               13
#
#             marital-status          occupation     relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# 1       Married-civ-spouse     Farming-fishing          Husband
# 2       Married-civ-spouse     Protective-serv          Husband
# 3       Married-civ-spouse   Machine-op-inspct          Husband
# 4            Never-married                   ?        Own-child
# ...                    ...                 ...              ...
# 16276             Divorced      Prof-specialty    Not-in-family
# 16277              Widowed                   ?   Other-relative
# 16278   Married-civ-spouse      Prof-specialty          Husband
# 16279             Divorced        Adm-clerical        Own-child
# 16280   Married-civ-spouse     Exec-managerial          Husband
#
#                       race   gender  capital-gain  capital-loss  \
# 0                    Black     Male             0             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male          7688             0
# 4                    White   Female             0             0
# ...                    ...      ...           ...           ...
# 16276                White   Female             0             0
# 16277                Black     Male             0             0
# 16278                White     Male             0             0
# 16279   Asian-Pac-Islander     Male          5455             0
# 16280                White     Male             0             0
#
#        hours-per-week  native-country   income
# 0                  40   United-States   <=50K.
# 1                  50   United-States   <=50K.
# 2                  40   United-States    >50K.
# 3                  40   United-States    >50K.
# 4                  30   United-States   <=50K.
# ...               ...             ...      ...
# 16276              36   United-States   <=50K.
# 16277              40   United-States   <=50K.
# 16278              50   United-States   <=50K.
# 16279              40   United-States   <=50K.
# 16280              60   United-States    >50K.
#
# [16281 rows x 16 columns]

# %%
(train.shape,test.shape)
# Out:
# ((32561, 15), (16281, 15))

# %%
train['gender'].replace(to_replace={' Male':1, ' Female' : 0}, inplace=True)
train['gender'] = train.gender.astype('uint8')

test['gender'].replace(to_replace={' Male':1, ' Female' : 0}, inplace=True)
test['gender'] = test.gender.astype('uint8')


# Convert race to white vs non-white
train.loc[train['race'] != ' White', 'race'] = 'Non-White'
test.loc[test['race'] != ' White', 'race'] = 'Non-White'
train.loc[train['race'] == ' White', 'race'] = 'White'
test.loc[test['race'] == ' White', 'race'] = 'White'

train['race'].replace(to_replace={'White':1, 'Non-White':0}, inplace=True)
train['race'] = train.race.astype('uint8')

test['race'].replace(to_replace={'White':1, 'Non-White':0}, inplace=True)
test['race'] = test.race.astype('uint8')

 # Convert native-country to american vs non-american
train.loc[train['native-country'] != ' United-States', 'native-country'] = 'Non-US'
train.loc[train['native-country'] == ' United-States', 'native-country'] = 'US'
test.loc[test['native-country'] != ' United-States', 'native-country'] = 'Non-US'
test.loc[test['native-country'] == ' United-States', 'native-country'] = 'US'
train['native-country'].replace(to_replace={'US':1, 'Non-US':0}, inplace=True)
train['native-country'] = train['native-country'].astype('uint8')

test['native-country'].replace(to_replace={'US':1, 'Non-US':0}, inplace=True)
test['native-country'] = test['native-country'].astype('uint8')

# %%
train
# Out:
#        age          workclass  fnlwgt    education  educational-num  \
# 0       39          State-gov   77516    Bachelors               13
# 1       50   Self-emp-not-inc   83311    Bachelors               13
# 2       38            Private  215646      HS-grad                9
# 3       53            Private  234721         11th                7
# 4       28            Private  338409    Bachelors               13
# ...    ...                ...     ...          ...              ...
# 32556   27            Private  257302   Assoc-acdm               12
# 32557   40            Private  154374      HS-grad                9
# 32558   58            Private  151910      HS-grad                9
# 32559   22            Private  201490      HS-grad                9
# 32560   52       Self-emp-inc  287927      HS-grad                9
#
#             marital-status          occupation    relationship  race  gender  \
# 0            Never-married        Adm-clerical   Not-in-family     1       1
# 1       Married-civ-spouse     Exec-managerial         Husband     1       1
# 2                 Divorced   Handlers-cleaners   Not-in-family     1       1
# 3       Married-civ-spouse   Handlers-cleaners         Husband     0       1
# 4       Married-civ-spouse      Prof-specialty            Wife     0       0
# ...                    ...                 ...             ...   ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife     1       0
# 32557   Married-civ-spouse   Machine-op-inspct         Husband     1       1
# 32558              Widowed        Adm-clerical       Unmarried     1       0
# 32559        Never-married        Adm-clerical       Own-child     1       1
# 32560   Married-civ-spouse     Exec-managerial            Wife     1       0
#
#        capital-gain  capital-loss  hours-per-week  native-country  income
# 0              2174             0              40               1   <=50K
# 1                 0             0              13               1   <=50K
# 2                 0             0              40               1   <=50K
# 3                 0             0              40               1   <=50K
# 4                 0             0              40               0   <=50K
# ...             ...           ...             ...             ...     ...
# 32556             0             0              38               1   <=50K
# 32557             0             0              40               1    >50K
# 32558             0             0              40               1   <=50K
# 32559             0             0              20               1   <=50K
# 32560         15024             0              40               1    >50K
#
# [32561 rows x 15 columns]

# %%
train.replace({" <=50K":0," >50K":1},inplace=True)
test.replace({" <=50K.":0," >50K.":1},inplace=True)

# %%
train.race.value_counts()
# Out:
# 1    27816
# 0     4745
# Name: race, dtype: int64

# %%
numeric_cols=list(train.select_dtypes(exclude=['object']).columns)
numeric_cols.remove('race')
numeric_cols.remove('gender')
numeric_cols.remove('native-country')
numeric_cols.remove('income')
numeric_cols

# %%
categorized_columns=list(train.select_dtypes(['object']).columns)
categorized_columns
# Out:
# ['workclass', 'education', 'marital-status', 'occupation', 'relationship']

# %%
from sklearn.preprocessing import StandardScaler
rb=StandardScaler()
train[numeric_cols]=rb.fit_transform(train[numeric_cols])
test[numeric_cols]=rb.transform(test[numeric_cols])

# %%
from sklearn.preprocessing import OneHotEncoder
onehot=OneHotEncoder(drop="first",handle_unknown='ignore',sparse_output=False)
train_n=onehot.fit_transform(train[categorized_columns])
test_n=onehot.transform(test[categorized_columns])

# %%
train_n=pd.DataFrame(train_n,columns=onehot.get_feature_names_out())
test_n=pd.DataFrame(test_n,columns=onehot.get_feature_names_out())

train_d=train.drop(categorized_columns,axis=1)
test_d=test.drop(categorized_columns,axis=1)

train_n=pd.concat([train_d,train_n],axis=1)
test_n=pd.concat([test_d,test_n],axis=1)

# %%
# train_n_target=train_n.income
# train_n.drop("income",axis=1,inplace=True)

test_n_target=test_n.income
test_n.drop("income",axis=1,inplace=True)

# %%
X_test,X_val,y_test,y_val=train_test_split(test_n,test_n_target,random_state=1,test_size=.2)

# %%
X_val_g=X_val.gender
X_val.drop("gender",axis=1,inplace=True)
X_test_g=X_test.gender
X_test.drop("gender",axis=1,inplace=True)

# %%
def multiply(x):
    v1,v2 = x
    if v1.shape!=v2.shape:
        v2=K.stack([v2]*v1.shape[-1], axis=-1)
        return v1*v2
    else:
        return v1*v2

# %%
x_train=train_n.copy()
Y_train=x_train.income
X_train=x_train.copy()
X_train.drop("income",axis=1,inplace=True)
gender=X_train.gender
X_train.drop("gender",axis=1,inplace=True)

# %%
X_train.shape
# Out:
# (32561, 56)

# %%
#Ours Architecture

input_layer=Input(shape=(X_train.shape[-1],),)
kernel=tf.keras.initializers.glorot_uniform
#Encoder block
x=Dense(64,activation="relu",kernel_initializer=kernel)(input_layer)
x=BatchNormalization()(x)
x=Dense(32,activation="relu",kernel_initializer=kernel)(x)
x=BatchNormalization()(x)
x=Dense(32,activation="relu",kernel_initializer=kernel)(x)
x=BatchNormalization()(x)
latent=Dense(16,activation="relu",kernel_initializer=kernel,name="latent_vector")(x)

#Decoder Block

z=Dense(32,activation="relu",kernel_initializer=kernel)(latent)
z=BatchNormalization()(z)
z=Dense(32,activation="relu",kernel_initializer=kernel)(z)
z=BatchNormalization()(z)
z=Dense(64,activation="relu",kernel_initializer=kernel)(z)
z=BatchNormalization()(z)
decoded=Dense(X_train.shape[-1],activation="relu",kernel_initializer=kernel,name="autoencoder")(z)

#Now Latent is distibuted in two parts

#This is the gender free sigmoid activation part

z1=Dense(8,activation="relu",kernel_initializer=kernel)(latent)
z1=BatchNormalization()(z1)
z1=Dense(16,activation="sigmoid",kernel_initializer=kernel,name="gender_free")(z1)

#This is the gender bias sigmoid activation part

z2=Dense(8,activation="relu",kernel_initializer=kernel)(latent)
z2=BatchNormalization()(z2)
z2=Dense(16,activation="sigmoid",kernel_initializer=kernel,name="gender_bias",)(z2)

z1=Lambda(multiply)([latent,z1])
#Assuming gender free component
gender_free=Lambda(multiply)([z1,1-z2])

#Assuming gender bias component
gender_bias=Lambda(multiply)([z2,latent])

z3=Dense(16,activation="relu",kernel_initializer=kernel)(gender_bias)
z3=Dropout(.2)(z3)
z3=Dense(8,activation="relu",kernel_initializer=kernel)(z3)
z3=Dropout(.2)(z3)
gender_output=Dense(1,activation='sigmoid',kernel_initializer=kernel,name="classification_gender")(z3)

#Downstream Task to predict the Output label

y=Dense(16,activation="relu",kernel_initializer=kernel)(gender_free)
y=Dropout(.2)(y)
y=Dense(8,activation="relu",kernel_initializer=kernel)(y)
y=Dropout(.2)(y)
output=Dense(1,activation='sigmoid',kernel_initializer=kernel,name="classification")(y)

base=Model(inputs=input_layer,outputs=[decoded,gender_output,output])

# %%
import keras.backend as K
losses = {
    "autoencoder": "mse",
    "classification":"binary_crossentropy",
    "classification_gender":"binary_crossentropy"
}

loss_weights = {
    "autoencoder": 1.0,
    "classification":3,
    "classification_gender":2
}

metrics = {
    "autoencoder": "mse",
    "classification": ["accuracy","Precision","Recall"],
    "classification_gender":["accuracy","Precision","Recall"]
}

base.compile(loss=losses,loss_weights=loss_weights, optimizer=tf.keras.optimizers.legacy.Adam(1e-3), metrics=metrics)

base.summary()
# Out:
# Model: "model_33"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 56)]         0           []
#
#  dense_71 (Dense)               (None, 64)           3648        ['input_7[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 64)          256         ['dense_71[0][0]']
#  ormalization)
#
#  dense_72 (Dense)               (None, 32)           2080        ['batch_normalization_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 32)          128         ['dense_72[0][0]']
#  ormalization)
#
#  dense_73 (Dense)               (None, 32)           1056        ['batch_normalization_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 32)          128         ['dense_73[0][0]']
#  ormalization)
#
#  latent_vector (Dense)          (None, 16)           528         ['batch_normalization_49[0][0]']
#
#  dense_78 (Dense)               (None, 8)            136         ['latent_vector[0][0]']
#
#  dense_77 (Dense)               (None, 8)            136         ['latent_vector[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 8)           32          ['dense_78[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 8)           32          ['dense_77[0][0]']
#  ormalization)
#
#  gender_bias (Dense)            (None, 16)           144         ['batch_normalization_54[0][0]']
#
#  gender_free (Dense)            (None, 16)           144         ['batch_normalization_53[0][0]']
#
#  dense_74 (Dense)               (None, 32)           544         ['latent_vector[0][0]']
#
#  lambda_17 (Lambda)             (None, 16)           0           ['latent_vector[0][0]',
#                                                                   'gender_free[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 16)          0           ['gender_bias[0][0]']
#  )
#
#  batch_normalization_50 (BatchN  (None, 32)          128         ['dense_74[0][0]']
#  ormalization)
#
#  lambda_19 (Lambda)             (None, 16)           0           ['gender_bias[0][0]',
#                                                                   'latent_vector[0][0]']
#
#  lambda_18 (Lambda)             (None, 16)           0           ['lambda_17[0][0]',
#                                                                   'tf.math.subtract_6[0][0]']
#
#  dense_75 (Dense)               (None, 32)           1056        ['batch_normalization_50[0][0]']
#
#  dense_79 (Dense)               (None, 16)           272         ['lambda_19[0][0]']
#
#  dense_81 (Dense)               (None, 16)           272         ['lambda_18[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 32)          128         ['dense_75[0][0]']
#  ormalization)
#
#  dropout_24 (Dropout)           (None, 16)           0           ['dense_79[0][0]']
#
#  dropout_26 (Dropout)           (None, 16)           0           ['dense_81[0][0]']
#
#  dense_76 (Dense)               (None, 64)           2112        ['batch_normalization_51[0][0]']
#
#  dense_80 (Dense)               (None, 8)            136         ['dropout_24[0][0]']
#
#  dense_82 (Dense)               (None, 8)            136         ['dropout_26[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 64)          256         ['dense_76[0][0]']
#  ormalization)
#
#  dropout_25 (Dropout)           (None, 8)            0           ['dense_80[0][0]']
#
#  dropout_27 (Dropout)           (None, 8)            0           ['dense_82[0][0]']
#
#  autoencoder (Dense)            (None, 56)           3640        ['batch_normalization_52[0][0]']
#
#  classification_gender (Dense)  (None, 1)            9           ['dropout_25[0][0]']
#
#  classification (Dense)         (None, 1)            9           ['dropout_27[0][0]']
#
# ==================================================================================================
# Total params: 17,146
# Trainable params: 16,602
# Non-trainable params: 544
# __________________________________________________________________________________________________

# %%
base.load_weights("adult_weights.h5")

# %%
import numpy as np
from keras.callbacks import LearningRateScheduler

def step_decay_schedule(initial_lr=1e-4, decay_factor=0.75, step_size=10):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        return initial_lr * (decay_factor ** np.floor(epoch/step_size))

    return LearningRateScheduler(schedule)

lr_sched = step_decay_schedule(initial_lr=1e-4, decay_factor=0.75, step_size=2)

# %%
print("TensorFlow version:", tf.__version__)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# TensorFlow version: 2.12.0
# Num GPUs Available:  0

# %%
from sklearn.metrics import log_loss
import math
import cvxpy as cp

def optim(loss, a, c):
  A = loss
  x = cp.Variable(loss.shape[0])
  objective = cp.Maximize(-a*cp.sum_squares(x)+cp.sum(cp.multiply(A,x)))
  constraints = [0 <= x, cp.sum(x) == c]
  prob = cp.Problem(objective, constraints)
  result = prob.solve()
  for i in range(x.value.shape[0]):
    if abs(x.value[i]) < 0.01 or x.value[i] < 0:
      x.value[i] = 0
  x.value = x.value
  return x.value

def dif(a, b):
  sum = 0
  for i in range(len(a)):
    sum += (a[i] - b[i]) ** 2
  sum0 = sum ** 0.5
  return sum0

# %%
import time
def Random_search(train, folds, param_range, num_param = 1):
    trainscore = []
    testscore = []
    K_values = sample(range(param_range[0],param_range[1]),num_param)
    K_values.sort()
    print('k range:',K_values)
    models=[]
    for k in tqdm(K_values):
        trainscore_folds = []
        testscore_folds = []
        for j in range(0, folds):
            k=48
            x_train=train_n.copy()
            iter = 0
            wi0 = np.ones((x_train.shape[0]))
            wi1 = wi0 + 10000000000000

            x_train_m=x_train[x_train.gender==1].copy()
            x_train_f=x_train[x_train.gender==0].copy()
            g_m=x_train_m.gender
            g_f=x_train_f.gender
            x_train_m.drop("gender",axis=1,inplace=True)
            x_train_f.drop("gender",axis=1,inplace=True)
            x_train_mp=x_train_m[x_train_m.income==1].copy()
            x_train_mn=x_train_m[x_train_m.income==0].copy()

            mp_label=x_train_mp.income
            mn_label=x_train_mn.income
            x_train_mp.drop("income",axis=1,inplace=True)
            x_train_mn.drop("income",axis=1,inplace=True)

            x_train_fp=x_train_f[x_train_f.income==1].copy()
            x_train_fn=x_train_f[x_train_f.income==0].copy()

            fp_label=x_train_fp.income
            fn_label=x_train_fn.income

            x_train_fp.drop("income",axis=1,inplace=True)
            x_train_fn.drop("income",axis=1,inplace=True)

            loss_mp = wi0_mp = np.ones(x_train_mp.shape[0])
            loss_mn = wi0_mn = np.ones(x_train_mn.shape[0])
            loss_fp = wi0_fp = np.ones(x_train_fp.shape[0])
            loss_fn = wi0_fn = np.ones(x_train_fn.shape[0])

            Y_train=x_train.income
            X_train=x_train.copy()
            X_train.drop("income",axis=1,inplace=True)
            gender=X_train.gender
            X_train.drop("gender",axis=1,inplace=True)
            Main=Model(inputs=input_layer,outputs=[decoded,gender_output,output])
            while iter<6:
                Main.compile(loss=losses,loss_weights=loss_weights, optimizer=tf.keras.optimizers.legacy.Adam(1e-4), metrics=metrics)
                start=time.time()
                hist = Main.fit(X_train,
                     {"autoencoder":X_train,  "classification":Y_train,
                      "classification_gender":gender},
                     verbose=1,
                     batch_size=32,
                     epochs=5,
                     sample_weight={"classification":pd.Series(wi0).to_frame("weight")},
                     validation_data=(X_val,{"autoencoder": X_val, "classification": y_val,
                                              "classification_gender":X_val_g}),
                     callbacks=[lr_sched])
                loss_mp = -(tf.math.log(Main.predict(x_train_mp)[2]+1e-10)).numpy().squeeze()
                loss_mn = -(tf.math.log(1-Main.predict(x_train_mn)[2]+1e-10)).numpy().squeeze()
                loss_fp = -(tf.math.log(Main.predict(x_train_fp)[2]+1e-10)).numpy().squeeze()
                loss_fn = -(tf.math.log(1-Main.predict(x_train_fn)[2]+1e-10)).numpy().squeeze()

                wi1 = wi0
                wi0_bp_1 = optim(loss_mp, k, x_train_mp.shape[0]//10)
                wi0_bn_1 = optim(loss_mn, k, x_train_mn.shape[0]//10)
                wi0_wp_1 = optim(loss_fp, k, x_train_fp.shape[0]//10)
                wi0_wn_1 = optim(loss_fn, k, x_train_fn.shape[0]//10)
                end=time.time()
                X_train = pd.concat([x_train_mp, x_train_mn, x_train_fp, x_train_fn],axis=0)
                Y_train = pd.concat((mp_label, mn_label, fp_label, fn_label),axis=0)
                wi0 = np.concatenate([wi0_bp_1, wi0_bn_1, wi0_wp_1, wi0_wn_1],axis=0)
                gender=pd.concat([g_m,g_f],axis=0)
                print(f"Running {iter}-{dif(wi0, wi1)} and time is {end-start}")
                iter = iter + 1
            Y_predicted = Main.predict(X_test)[1].squeeze()>.5
            testscore_folds.append(np.sum(y_test == Y_predicted)/len(y_test))
            Y_predicted = Main.predict(X_train)[1].squeeze()>.5
            trainscore_folds.append(np.sum(Y_train == Y_predicted)/len(Y_train))
            models.append(Main)
            print(f"accuracy is {np.sum(Y_train == Y_predicted)/len(Y_train)}")
        trainscore.append(np.mean(np.array(trainscore_folds)))
        testscore.append(np.mean(np.array(testscore_folds)))
    return trainscore, testscore , K_values,models

# %%
x_train.shape
# Out:
# (32561, 58)

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import random
import warnings
from tqdm import tqdm

warnings.filterwarnings("ignore")

from random import sample
c=100
param_min = 20
param_max = 100
k_fold = 1
param_range = (param_min, param_max)
trainscore, testscore, K_values,models = Random_search(x_train, k_fold, param_range)
# Out:
# k range: [94]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1/5
# 1018/1018 [==============================] - 13s 8ms/step - loss: 1.7373 - autoencoder_loss: 0.0885 - classification_gender_loss: 0.3007 - classification_loss: 0.3491 - autoencoder_mse: 0.0885 - classification_gender_accuracy: 0.8467 - classification_gender_precision: 0.9015 - classification_gender_recall: 0.8655 - classification_accuracy: 0.8443 - classification_precision_1: 0.7145 - classification_recall_1: 0.5884 - val_loss: 1.6709 - val_autoencoder_loss: 0.0864 - val_classification_gender_loss: 0.3067 - val_classification_loss: 0.3237 - val_autoencoder_mse: 0.0864 - val_classification_gender_accuracy: 0.8413 - val_classification_gender_precision: 0.9009 - val_classification_gender_recall: 0.8546 - val_classification_accuracy: 0.8459 - val_classification_precision_1: 0.7288 - val_classification_recall_1: 0.5637 - lr: 1.0000e-04
# Epoch 2/5
# 1018/1018 [==============================] - 14s 13ms/step - loss: 1.7233 - autoencoder_loss: 0.0888 - classification_gender_loss: 0.3024 - classification_loss: 0.3432 - autoencoder_mse: 0.0888 - classification_gender_accuracy: 0.8451 - classification_gender_precision: 0.8999 - classification_gender_recall: 0.8646 - classification_accuracy: 0.8452 - classification_precision_1: 0.7097 - classification_recall_1: 0.6048 - val_loss: 1.6646 - val_autoencoder_loss: 0.0867 - val_classification_gender_loss: 0.3070 - val_classification_loss: 0.3213 - val_autoencoder_mse: 0.0867 - val_classification_gender_accuracy: 0.8440 - val_classification_gender_precision: 0.8998 - val_classification_gender_recall: 0.8606 - val_classification_accuracy: 0.8446 - val_classification_precision_1: 0.7189 - val_classification_recall_1: 0.5727 - lr: 1.0000e-04
# Epoch 3/5
# 1018/1018 [==============================] - 17s 17ms/step - loss: 1.7167 - autoencoder_loss: 0.0883 - classification_gender_loss: 0.3030 - classification_loss: 0.3408 - autoencoder_mse: 0.0883 - classification_gender_accuracy: 0.8455 - classification_gender_precision: 0.9030 - classification_gender_recall: 0.8618 - classification_accuracy: 0.8479 - classification_precision_1: 0.7176 - classification_recall_1: 0.6071 - val_loss: 1.6580 - val_autoencoder_loss: 0.0859 - val_classification_gender_loss: 0.3069 - val_classification_loss: 0.3195 - val_autoencoder_mse: 0.0859 - val_classification_gender_accuracy: 0.8400 - val_classification_gender_precision: 0.8938 - val_classification_gender_recall: 0.8610 - val_classification_accuracy: 0.8480 - val_classification_precision_1: 0.7260 - val_classification_recall_1: 0.5830 - lr: 7.5000e-05
# Epoch 4/5
# 1018/1018 [==============================] - 14s 14ms/step - loss: 1.7074 - autoencoder_loss: 0.0884 - classification_gender_loss: 0.3006 - classification_loss: 0.3393 - autoencoder_mse: 0.0884 - classification_gender_accuracy: 0.8459 - classification_gender_precision: 0.8992 - classification_gender_recall: 0.8669 - classification_accuracy: 0.8461 - classification_precision_1: 0.7113 - classification_recall_1: 0.6076 - val_loss: 1.6557 - val_autoencoder_loss: 0.0868 - val_classification_gender_loss: 0.3057 - val_classification_loss: 0.3191 - val_autoencoder_mse: 0.0868 - val_classification_gender_accuracy: 0.8416 - val_classification_gender_precision: 0.9009 - val_classification_gender_recall: 0.8550 - val_classification_accuracy: 0.8486 - val_classification_precision_1: 0.7247 - val_classification_recall_1: 0.5894 - lr: 7.5000e-05
# Epoch 5/5
# 1018/1018 [==============================] - 7s 7ms/step - loss: 1.7078 - autoencoder_loss: 0.0880 - classification_gender_loss: 0.3007 - classification_loss: 0.3394 - autoencoder_mse: 0.0880 - classification_gender_accuracy: 0.8484 - classification_gender_precision: 0.9036 - classification_gender_recall: 0.8658 - classification_accuracy: 0.8462 - classification_precision_1: 0.7144 - classification_recall_1: 0.6021 - val_loss: 1.6532 - val_autoencoder_loss: 0.0853 - val_classification_gender_loss: 0.3063 - val_classification_loss: 0.3184 - val_autoencoder_mse: 0.0853 - val_classification_gender_accuracy: 0.8428 - val_classification_gender_precision: 0.9023 - val_classification_gender_recall: 0.8555 - val_classification_accuracy: 0.8477 - val_classification_precision_1: 0.7285 - val_classification_recall_1: 0.5766 - lr: 5.6250e-05
# 209/209 [==============================] - 1s 2ms/step
# 473/473 [==============================] - 1s 2ms/step
# 37/37 [==============================] - 0s 2ms/step
# 300/300 [==============================] - 1s 2ms/step
# Running 0-162.41556296143116 and time is 92.63320636749268
# Epoch 1/5
# 1018/1018 [==============================] - 13s 7ms/step - loss: 0.7991 - autoencoder_loss: 0.0883 - classification_gender_loss: 0.3021 - classification_loss: 0.0355 - autoencoder_mse: 0.0883 - classification_gender_accuracy: 0.8460 - classification_gender_precision: 0.9000 - classification_gender_recall: 0.8661 - classification_accuracy: 0.8477 - classification_precision_1: 0.7208 - classification_recall_1: 0.5997 - val_loss: 1.6561 - val_autoencoder_loss: 0.0843 - val_classification_gender_loss: 0.3057 - val_classification_loss: 0.3201 - val_autoencoder_mse: 0.0843 - val_classification_gender_accuracy: 0.8428 - val_classification_gender_precision: 0.8988 - val_classification_gender_recall: 0.8597 - val_classification_accuracy: 0.8496 - val_classification_precision_1: 0.7436 - val_classification_recall_1: 0.5637 - lr: 1.0000e-04
# Epoch 2/5
# 1018/1018 [==============================] - 9s 8ms/step - loss: 0.7952 - autoencoder_loss: 0.0877 - classification_gender_loss: 0.3006 - classification_loss: 0.0355 - autoencoder_mse: 0.0877 - classification_gender_accuracy: 0.8484 - classification_gender_precision: 0.9042 - classification_gender_recall: 0.8652 - classification_accuracy: 0.8487 - classification_precision_1: 0.7302 - classification_recall_1: 0.5898 - val_loss: 1.6547 - val_autoencoder_loss: 0.0823 - val_classification_gender_loss: 0.3056 - val_classification_loss: 0.3204 - val_autoencoder_mse: 0.0823 - val_classification_gender_accuracy: 0.8446 - val_classification_gender_precision: 0.9018 - val_classification_gender_recall: 0.8592 - val_classification_accuracy: 0.8468 - val_classification_precision_1: 0.7364 - val_classification_recall_1: 0.5573 - lr: 1.0000e-04
# Epoch 3/5
# 1018/1018 [==============================] - 7s 7ms/step - loss: 0.7900 - autoencoder_loss: 0.0870 - classification_gender_loss: 0.2984 - classification_loss: 0.0354 - autoencoder_mse: 0.0870 - classification_gender_accuracy: 0.8487 - classification_gender_precision: 0.9023 - classification_gender_recall: 0.8679 - classification_accuracy: 0.8493 - classification_precision_1: 0.7308 - classification_recall_1: 0.5924 - val_loss: 1.6510 - val_autoencoder_loss: 0.0815 - val_classification_gender_loss: 0.3047 - val_classification_loss: 0.3200 - val_autoencoder_mse: 0.0815 - val_classification_gender_accuracy: 0.8462 - val_classification_gender_precision: 0.9024 - val_classification_gender_recall: 0.8610 - val_classification_accuracy: 0.8465 - val_classification_precision_1: 0.7282 - val_classification_recall_1: 0.5689 - lr: 7.5000e-05
# Epoch 4/5
# 1018/1018 [==============================] - 8s 7ms/step - loss: 0.7872 - autoencoder_loss: 0.0868 - classification_gender_loss: 0.2969 - classification_loss: 0.0355 - autoencoder_mse: 0.0868 - classification_gender_accuracy: 0.8488 - classification_gender_precision: 0.9055 - classification_gender_recall: 0.8642 - classification_accuracy: 0.8476 - classification_precision_1: 0.7255 - classification_recall_1: 0.5906 - val_loss: 1.6549 - val_autoencoder_loss: 0.0813 - val_classification_gender_loss: 0.3056 - val_classification_loss: 0.3208 - val_autoencoder_mse: 0.0813 - val_classification_gender_accuracy: 0.8446 - val_classification_gender_precision: 0.9006 - val_classification_gender_recall: 0.8606 - val_classification_accuracy: 0.8459 - val_classification_precision_1: 0.7250 - val_classification_recall_1: 0.5701 - lr: 7.5000e-05
# Epoch 5/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7853 - autoencoder_loss: 0.0863 - classification_gender_loss: 0.2963 - classification_loss: 0.0355 - autoencoder_mse: 0.0863 - classification_gender_accuracy: 0.8506 - classification_gender_precision: 0.9050 - classification_gender_recall: 0.8679 - classification_accuracy: 0.8480 - classification_precision_1: 0.7270 - classification_recall_1: 0.5906 - val_loss: 1.6566 - val_autoencoder_loss: 0.0808 - val_classification_gender_loss: 0.3060 - val_classification_loss: 0.3213 - val_autoencoder_mse: 0.0808 - val_classification_gender_accuracy: 0.8449 - val_classification_gender_precision: 0.8991 - val_classification_gender_recall: 0.8629 - val_classification_accuracy: 0.8465 - val_classification_precision_1: 0.7297 - val_classification_recall_1: 0.5663 - lr: 5.6250e-05
# 209/209 [==============================] - 1s 2ms/step
# 473/473 [==============================] - 1s 2ms/step
# 37/37 [==============================] - 0s 2ms/step
# 300/300 [==============================] - 1s 2ms/step
# Running 1-0.10117384749184284 and time is 48.56005501747131
# Epoch 1/5
# 1018/1018 [==============================] - 15s 9ms/step - loss: 0.7885 - autoencoder_loss: 0.0862 - classification_gender_loss: 0.2978 - classification_loss: 0.0356 - autoencoder_mse: 0.0862 - classification_gender_accuracy: 0.8500 - classification_gender_precision: 0.9028 - classification_gender_recall: 0.8696 - classification_accuracy: 0.8465 - classification_precision_1: 0.7225 - classification_recall_1: 0.5884 - val_loss: 1.6535 - val_autoencoder_loss: 0.0805 - val_classification_gender_loss: 0.3051 - val_classification_loss: 0.3209 - val_autoencoder_mse: 0.0805 - val_classification_gender_accuracy: 0.8431 - val_classification_gender_precision: 0.9027 - val_classification_gender_recall: 0.8555 - val_classification_accuracy: 0.8449 - val_classification_precision_1: 0.7208 - val_classification_recall_1: 0.5714 - lr: 1.0000e-04
# Epoch 2/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7892 - autoencoder_loss: 0.0862 - classification_gender_loss: 0.2986 - classification_loss: 0.0353 - autoencoder_mse: 0.0862 - classification_gender_accuracy: 0.8509 - classification_gender_precision: 0.9043 - classification_gender_recall: 0.8692 - classification_accuracy: 0.8491 - classification_precision_1: 0.7319 - classification_recall_1: 0.5893 - val_loss: 1.6517 - val_autoencoder_loss: 0.0799 - val_classification_gender_loss: 0.3033 - val_classification_loss: 0.3217 - val_autoencoder_mse: 0.0799 - val_classification_gender_accuracy: 0.8425 - val_classification_gender_precision: 0.9038 - val_classification_gender_recall: 0.8532 - val_classification_accuracy: 0.8474 - val_classification_precision_1: 0.7341 - val_classification_recall_1: 0.5650 - lr: 1.0000e-04
# Epoch 3/5
# 1018/1018 [==============================] - 6s 6ms/step - loss: 0.7846 - autoencoder_loss: 0.0857 - classification_gender_loss: 0.2966 - classification_loss: 0.0352 - autoencoder_mse: 0.0857 - classification_gender_accuracy: 0.8514 - classification_gender_precision: 0.9036 - classification_gender_recall: 0.8709 - classification_accuracy: 0.8488 - classification_precision_1: 0.7272 - classification_recall_1: 0.5953 - val_loss: 1.6573 - val_autoencoder_loss: 0.0794 - val_classification_gender_loss: 0.3049 - val_classification_loss: 0.3227 - val_autoencoder_mse: 0.0794 - val_classification_gender_accuracy: 0.8431 - val_classification_gender_precision: 0.9055 - val_classification_gender_recall: 0.8522 - val_classification_accuracy: 0.8489 - val_classification_precision_1: 0.7411 - val_classification_recall_1: 0.5637 - lr: 7.5000e-05
# Epoch 4/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7844 - autoencoder_loss: 0.0857 - classification_gender_loss: 0.2962 - classification_loss: 0.0354 - autoencoder_mse: 0.0857 - classification_gender_accuracy: 0.8509 - classification_gender_precision: 0.9037 - classification_gender_recall: 0.8699 - classification_accuracy: 0.8474 - classification_precision_1: 0.7241 - classification_recall_1: 0.5916 - val_loss: 1.6558 - val_autoencoder_loss: 0.0791 - val_classification_gender_loss: 0.3050 - val_classification_loss: 0.3222 - val_autoencoder_mse: 0.0791 - val_classification_gender_accuracy: 0.8434 - val_classification_gender_precision: 0.9036 - val_classification_gender_recall: 0.8550 - val_classification_accuracy: 0.8465 - val_classification_precision_1: 0.7343 - val_classification_recall_1: 0.5586 - lr: 7.5000e-05
# Epoch 5/5
# 1018/1018 [==============================] - 6s 6ms/step - loss: 0.7813 - autoencoder_loss: 0.0853 - classification_gender_loss: 0.2952 - classification_loss: 0.0352 - autoencoder_mse: 0.0853 - classification_gender_accuracy: 0.8496 - classification_gender_precision: 0.9047 - classification_gender_recall: 0.8666 - classification_accuracy: 0.8484 - classification_precision_1: 0.7292 - classification_recall_1: 0.5892 - val_loss: 1.6531 - val_autoencoder_loss: 0.0793 - val_classification_gender_loss: 0.3041 - val_classification_loss: 0.3219 - val_autoencoder_mse: 0.0793 - val_classification_gender_accuracy: 0.8446 - val_classification_gender_precision: 0.9065 - val_classification_gender_recall: 0.8536 - val_classification_accuracy: 0.8449 - val_classification_precision_1: 0.7267 - val_classification_recall_1: 0.5611 - lr: 5.6250e-05
# 209/209 [==============================] - 1s 3ms/step
# 473/473 [==============================] - 2s 3ms/step
# 37/37 [==============================] - 0s 2ms/step
# 300/300 [==============================] - 1s 2ms/step
# Running 2-0.060570607419749525 and time is 49.598897218704224
# Epoch 1/5
# 1018/1018 [==============================] - 13s 9ms/step - loss: 0.7872 - autoencoder_loss: 0.0852 - classification_gender_loss: 0.2976 - classification_loss: 0.0356 - autoencoder_mse: 0.0852 - classification_gender_accuracy: 0.8508 - classification_gender_precision: 0.9016 - classification_gender_recall: 0.8721 - classification_accuracy: 0.8468 - classification_precision_1: 0.7239 - classification_recall_1: 0.5884 - val_loss: 1.6533 - val_autoencoder_loss: 0.0788 - val_classification_gender_loss: 0.3039 - val_classification_loss: 0.3222 - val_autoencoder_mse: 0.0788 - val_classification_gender_accuracy: 0.8477 - val_classification_gender_precision: 0.9000 - val_classification_gender_recall: 0.8666 - val_classification_accuracy: 0.8456 - val_classification_precision_1: 0.7276 - val_classification_recall_1: 0.5637 - lr: 1.0000e-04
# Epoch 2/5
# 1018/1018 [==============================] - 7s 7ms/step - loss: 0.7818 - autoencoder_loss: 0.0851 - classification_gender_loss: 0.2952 - classification_loss: 0.0355 - autoencoder_mse: 0.0851 - classification_gender_accuracy: 0.8506 - classification_gender_precision: 0.9037 - classification_gender_recall: 0.8694 - classification_accuracy: 0.8459 - classification_precision_1: 0.7235 - classification_recall_1: 0.5825 - val_loss: 1.6531 - val_autoencoder_loss: 0.0788 - val_classification_gender_loss: 0.3044 - val_classification_loss: 0.3219 - val_autoencoder_mse: 0.0788 - val_classification_gender_accuracy: 0.8456 - val_classification_gender_precision: 0.9008 - val_classification_gender_recall: 0.8620 - val_classification_accuracy: 0.8471 - val_classification_precision_1: 0.7345 - val_classification_recall_1: 0.5624 - lr: 1.0000e-04
# Epoch 3/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7776 - autoencoder_loss: 0.0847 - classification_gender_loss: 0.2933 - classification_loss: 0.0354 - autoencoder_mse: 0.0847 - classification_gender_accuracy: 0.8528 - classification_gender_precision: 0.9029 - classification_gender_recall: 0.8740 - classification_accuracy: 0.8479 - classification_precision_1: 0.7247 - classification_recall_1: 0.5943 - val_loss: 1.6480 - val_autoencoder_loss: 0.0778 - val_classification_gender_loss: 0.3038 - val_classification_loss: 0.3209 - val_autoencoder_mse: 0.0778 - val_classification_gender_accuracy: 0.8471 - val_classification_gender_precision: 0.9006 - val_classification_gender_recall: 0.8648 - val_classification_accuracy: 0.8486 - val_classification_precision_1: 0.7336 - val_classification_recall_1: 0.5740 - lr: 7.5000e-05
# Epoch 4/5
# 1018/1018 [==============================] - 7s 7ms/step - loss: 0.7755 - autoencoder_loss: 0.0845 - classification_gender_loss: 0.2929 - classification_loss: 0.0351 - autoencoder_mse: 0.0845 - classification_gender_accuracy: 0.8523 - classification_gender_precision: 0.9054 - classification_gender_recall: 0.8703 - classification_accuracy: 0.8493 - classification_precision_1: 0.7339 - classification_recall_1: 0.5873 - val_loss: 1.6513 - val_autoencoder_loss: 0.0779 - val_classification_gender_loss: 0.3044 - val_classification_loss: 0.3215 - val_autoencoder_mse: 0.0779 - val_classification_gender_accuracy: 0.8471 - val_classification_gender_precision: 0.8983 - val_classification_gender_recall: 0.8675 - val_classification_accuracy: 0.8474 - val_classification_precision_1: 0.7341 - val_classification_recall_1: 0.5650 - lr: 7.5000e-05
# Epoch 5/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7745 - autoencoder_loss: 0.0842 - classification_gender_loss: 0.2920 - classification_loss: 0.0354 - autoencoder_mse: 0.0842 - classification_gender_accuracy: 0.8532 - classification_gender_precision: 0.9045 - classification_gender_recall: 0.8728 - classification_accuracy: 0.8466 - classification_precision_1: 0.7265 - classification_recall_1: 0.5819 - val_loss: 1.6480 - val_autoencoder_loss: 0.0778 - val_classification_gender_loss: 0.3039 - val_classification_loss: 0.3208 - val_autoencoder_mse: 0.0778 - val_classification_gender_accuracy: 0.8486 - val_classification_gender_precision: 0.9052 - val_classification_gender_recall: 0.8620 - val_classification_accuracy: 0.8483 - val_classification_precision_1: 0.7293 - val_classification_recall_1: 0.5792 - lr: 5.6250e-05
# 209/209 [==============================] - 1s 2ms/step
# 473/473 [==============================] - 1s 2ms/step
# 37/37 [==============================] - 0s 2ms/step
# 300/300 [==============================] - 1s 2ms/step
# Running 3-0.06224418413395997 and time is 48.42810559272766
# Epoch 1/5
# 1018/1018 [==============================] - 13s 8ms/step - loss: 0.7772 - autoencoder_loss: 0.0842 - classification_gender_loss: 0.2933 - classification_loss: 0.0355 - autoencoder_mse: 0.0842 - classification_gender_accuracy: 0.8511 - classification_gender_precision: 0.9031 - classification_gender_recall: 0.8710 - classification_accuracy: 0.8475 - classification_precision_1: 0.7249 - classification_recall_1: 0.5914 - val_loss: 1.6513 - val_autoencoder_loss: 0.0776 - val_classification_gender_loss: 0.3032 - val_classification_loss: 0.3224 - val_autoencoder_mse: 0.0776 - val_classification_gender_accuracy: 0.8428 - val_classification_gender_precision: 0.9011 - val_classification_gender_recall: 0.8569 - val_classification_accuracy: 0.8468 - val_classification_precision_1: 0.7430 - val_classification_recall_1: 0.5470 - lr: 1.0000e-04
# Epoch 2/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7758 - autoencoder_loss: 0.0840 - classification_gender_loss: 0.2928 - classification_loss: 0.0354 - autoencoder_mse: 0.0840 - classification_gender_accuracy: 0.8536 - classification_gender_precision: 0.9057 - classification_gender_recall: 0.8720 - classification_accuracy: 0.8474 - classification_precision_1: 0.7297 - classification_recall_1: 0.5819 - val_loss: 1.6502 - val_autoencoder_loss: 0.0772 - val_classification_gender_loss: 0.3051 - val_classification_loss: 0.3209 - val_autoencoder_mse: 0.0772 - val_classification_gender_accuracy: 0.8468 - val_classification_gender_precision: 0.8930 - val_classification_gender_recall: 0.8736 - val_classification_accuracy: 0.8471 - val_classification_precision_1: 0.7298 - val_classification_recall_1: 0.5701 - lr: 1.0000e-04
# Epoch 3/5
# 1018/1018 [==============================] - 10s 10ms/step - loss: 0.7705 - autoencoder_loss: 0.0836 - classification_gender_loss: 0.2906 - classification_loss: 0.0352 - autoencoder_mse: 0.0836 - classification_gender_accuracy: 0.8532 - classification_gender_precision: 0.9023 - classification_gender_recall: 0.8754 - classification_accuracy: 0.8472 - classification_precision_1: 0.7303 - classification_recall_1: 0.5798 - val_loss: 1.6523 - val_autoencoder_loss: 0.0768 - val_classification_gender_loss: 0.3049 - val_classification_loss: 0.3219 - val_autoencoder_mse: 0.0768 - val_classification_gender_accuracy: 0.8459 - val_classification_gender_precision: 0.8985 - val_classification_gender_recall: 0.8652 - val_classification_accuracy: 0.8486 - val_classification_precision_1: 0.7448 - val_classification_recall_1: 0.5560 - lr: 7.5000e-05
# Epoch 4/5
# 1018/1018 [==============================] - 7s 7ms/step - loss: 0.7752 - autoencoder_loss: 0.0837 - classification_gender_loss: 0.2930 - classification_loss: 0.0351 - autoencoder_mse: 0.0837 - classification_gender_accuracy: 0.8517 - classification_gender_precision: 0.9014 - classification_gender_recall: 0.8739 - classification_accuracy: 0.8486 - classification_precision_1: 0.7362 - classification_recall_1: 0.5786 - val_loss: 1.6534 - val_autoencoder_loss: 0.0775 - val_classification_gender_loss: 0.3052 - val_classification_loss: 0.3218 - val_autoencoder_mse: 0.0775 - val_classification_gender_accuracy: 0.8449 - val_classification_gender_precision: 0.8991 - val_classification_gender_recall: 0.8629 - val_classification_accuracy: 0.8492 - val_classification_precision_1: 0.7466 - val_classification_recall_1: 0.5573 - lr: 7.5000e-05
# Epoch 5/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7699 - autoencoder_loss: 0.0834 - classification_gender_loss: 0.2905 - classification_loss: 0.0352 - autoencoder_mse: 0.0834 - classification_gender_accuracy: 0.8524 - classification_gender_precision: 0.9019 - classification_gender_recall: 0.8746 - classification_accuracy: 0.8478 - classification_precision_1: 0.7328 - classification_recall_1: 0.5791 - val_loss: 1.6496 - val_autoencoder_loss: 0.0766 - val_classification_gender_loss: 0.3051 - val_classification_loss: 0.3209 - val_autoencoder_mse: 0.0766 - val_classification_gender_accuracy: 0.8437 - val_classification_gender_precision: 0.8944 - val_classification_gender_recall: 0.8666 - val_classification_accuracy: 0.8480 - val_classification_precision_1: 0.7390 - val_classification_recall_1: 0.5611 - lr: 5.6250e-05
# 209/209 [==============================] - 1s 2ms/step
# 473/473 [==============================] - 1s 2ms/step
# 37/37 [==============================] - 0s 2ms/step
# 300/300 [==============================] - 1s 2ms/step
# Running 4-0.07336049082135064 and time is 51.48556733131409
# Epoch 1/5
# 1018/1018 [==============================] - 13s 8ms/step - loss: 0.7711 - autoencoder_loss: 0.0835 - classification_gender_loss: 0.2909 - classification_loss: 0.0353 - autoencoder_mse: 0.0835 - classification_gender_accuracy: 0.8524 - classification_gender_precision: 0.9046 - classification_gender_recall: 0.8713 - classification_accuracy: 0.8484 - classification_precision_1: 0.7322 - classification_recall_1: 0.5841 - val_loss: 1.6459 - val_autoencoder_loss: 0.0774 - val_classification_gender_loss: 0.3038 - val_classification_loss: 0.3203 - val_autoencoder_mse: 0.0774 - val_classification_gender_accuracy: 0.8453 - val_classification_gender_precision: 0.8969 - val_classification_gender_recall: 0.8661 - val_classification_accuracy: 0.8480 - val_classification_precision_1: 0.7260 - val_classification_recall_1: 0.5830 - lr: 1.0000e-04
# Epoch 2/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7695 - autoencoder_loss: 0.0833 - classification_gender_loss: 0.2900 - classification_loss: 0.0354 - autoencoder_mse: 0.0833 - classification_gender_accuracy: 0.8549 - classification_gender_precision: 0.9052 - classification_gender_recall: 0.8747 - classification_accuracy: 0.8473 - classification_precision_1: 0.7241 - classification_recall_1: 0.5913 - val_loss: 1.6480 - val_autoencoder_loss: 0.0767 - val_classification_gender_loss: 0.3047 - val_classification_loss: 0.3206 - val_autoencoder_mse: 0.0767 - val_classification_gender_accuracy: 0.8468 - val_classification_gender_precision: 0.8952 - val_classification_gender_recall: 0.8708 - val_classification_accuracy: 0.8486 - val_classification_precision_1: 0.7328 - val_classification_recall_1: 0.5753 - lr: 1.0000e-04
# Epoch 3/5
# 1018/1018 [==============================] - 7s 7ms/step - loss: 0.7662 - autoencoder_loss: 0.0829 - classification_gender_loss: 0.2886 - classification_loss: 0.0354 - autoencoder_mse: 0.0829 - classification_gender_accuracy: 0.8530 - classification_gender_precision: 0.9008 - classification_gender_recall: 0.8769 - classification_accuracy: 0.8472 - classification_precision_1: 0.7284 - classification_recall_1: 0.5826 - val_loss: 1.6485 - val_autoencoder_loss: 0.0761 - val_classification_gender_loss: 0.3048 - val_classification_loss: 0.3209 - val_autoencoder_mse: 0.0761 - val_classification_gender_accuracy: 0.8459 - val_classification_gender_precision: 0.8985 - val_classification_gender_recall: 0.8652 - val_classification_accuracy: 0.8474 - val_classification_precision_1: 0.7341 - val_classification_recall_1: 0.5650 - lr: 7.5000e-05
# Epoch 4/5
# 1018/1018 [==============================] - 8s 8ms/step - loss: 0.7650 - autoencoder_loss: 0.0829 - classification_gender_loss: 0.2881 - classification_loss: 0.0353 - autoencoder_mse: 0.0829 - classification_gender_accuracy: 0.8535 - classification_gender_precision: 0.9032 - classification_gender_recall: 0.8749 - classification_accuracy: 0.8483 - classification_precision_1: 0.7324 - classification_recall_1: 0.5828 - val_loss: 1.6480 - val_autoencoder_loss: 0.0763 - val_classification_gender_loss: 0.3049 - val_classification_loss: 0.3206 - val_autoencoder_mse: 0.0763 - val_classification_gender_accuracy: 0.8428 - val_classification_gender_precision: 0.8935 - val_classification_gender_recall: 0.8661 - val_classification_accuracy: 0.8477 - val_classification_precision_1: 0.7369 - val_classification_recall_1: 0.5624 - lr: 7.5000e-05
# Epoch 5/5
# 1018/1018 [==============================] - 7s 7ms/step - loss: 0.7637 - autoencoder_loss: 0.0826 - classification_gender_loss: 0.2879 - classification_loss: 0.0351 - autoencoder_mse: 0.0826 - classification_gender_accuracy: 0.8554 - classification_gender_precision: 0.9059 - classification_gender_recall: 0.8748 - classification_accuracy: 0.8468 - classification_precision_1: 0.7262 - classification_recall_1: 0.5839 - val_loss: 1.6451 - val_autoencoder_loss: 0.0760 - val_classification_gender_loss: 0.3043 - val_classification_loss: 0.3202 - val_autoencoder_mse: 0.0760 - val_classification_gender_accuracy: 0.8456 - val_classification_gender_precision: 0.8958 - val_classification_gender_recall: 0.8680 - val_classification_accuracy: 0.8477 - val_classification_precision_1: 0.7410 - val_classification_recall_1: 0.5560 - lr: 5.6250e-05
# 209/209 [==============================] - 1s 4ms/step
# 473/473 [==============================] - 1s 2ms/step
# 37/37 [==============================] - 0s 3ms/step
# 300/300 [==============================] - 1s 2ms/step
# Running 5-0.05330876174815268 and time is 51.47003769874573
# 407/407 [==============================] - 1s 2ms/step
# 1018/1018 [==============================] - 2s 2ms/step
# 100%|██████████| 1/1 [05:47<00:00, 347.41s/it]
# accuracy is 0.521390620681183

# %%
model3=base

# %%
model3.load_weights("adult_weights_changed.h5")

# %%
#MLP
Male=X_test[X_test_g==1]
Female=X_test[X_test_g==0]
Male_target=y_test[X_test_g==1]
Female_target=y_test[X_test_g==0]

print(f"The Accuracy for Male  is {((model3.predict(Male)[2].squeeze()>.5)==Male_target).sum()/Male_target.shape[0]}")
print(f"The Accuracy for Female  is {((model3.predict(Female)[2].squeeze()>.5)==Female_target).sum()/Female_target.shape[0]}")
# Out:
# 272/272 [==============================] - 1s 3ms/step
# The Accuracy for Male  is 0.818871394092633
# 136/136 [==============================] - 0s 3ms/step
# The Accuracy for Female  is 0.9269026139255147

# %%
Class_0=X_test[y_test==0]
Class_1=X_test[y_test==1]
Class_0_g=X_test_g[y_test==0]
Class_1_g=X_test_g[y_test==1]
Class_0_target=y_test[y_test==0]
Class_1_target=y_test[y_test==1]


print(f"The class accuracy for class 0 is {((model3.predict(Class_0)[2].squeeze()>.5)==Class_0_target).sum()/Class_0_target.shape[0]}")
print(f"The class accuracy for class 1 is {((model3.predict(Class_1)[2].squeeze()>.5)==Class_1_target).sum()/Class_1_target.shape[0]}")


gender={1:' Male', 0:' Female'}
for x,_ in Class_0_g.value_counts().items():
    print(x)
    idx=Class_0_g==x
    print(f"The Class 0 and Gender {gender[x]} accuracy is {((model3.predict(Class_0[idx])[2].squeeze()>.5)==Class_0_target[idx]).sum()/Class_0_target[idx].shape[0]}")

for x,_ in Class_1_g.value_counts().items():
    idx=Class_1_g==x
    print(f"The Class 1 and Gender {gender[x]} accuracy is {((model3.predict(Class_1[idx])[2].squeeze()>.5)==Class_1_target[idx]).sum()/Class_1_target[idx].shape[0]}")
# Out:
# 312/312 [==============================] - 1s 2ms/step
# The class accuracy for class 0 is 0.9425414364640884
# 96/96 [==============================] - 0s 2ms/step
# The class accuracy for class 1 is 0.5698924731182796
# 1
# 192/192 [==============================] - 0s 2ms/step
# The Class 0 and Gender  Male accuracy is 0.9215044971381848
# 0
# 120/120 [==============================] - 0s 2ms/step
# The Class 0 and Gender  Female accuracy is 0.9760416666666667
# 81/81 [==============================] - 0s 2ms/step
# The Class 1 and Gender  Male accuracy is 0.5761794276875484
# 16/16 [==============================] - 0s 2ms/step
# The Class 1 and Gender  Female accuracy is 0.5362318840579711

# %%
print(f"Overall accuracy is {((model3.predict(X_test)[2].squeeze()>.5)==y_test).sum()/y_test.shape[0]}")
# Out:
# 407/407 [==============================] - 4s 9ms/step
# Overall accuracy is 0.8379914004914005

# %%
def model_eval(actual, pred):
    actual.reset_index()
    confusion = pd.crosstab(actual, pred, rownames=['Actual'], colnames=['Predicted'])
    TP = confusion.loc[1,1]
    TN = confusion.loc[0,0]
    FP = confusion.loc[0,1]
    FN = confusion.loc[1,0]
    out = {}
    out['ALL'] = (TP+TN+FP+FN)
    out['DP'] = (TP+FP)/(TP+TN+FP+FN)
    out['TPR'] =  TP/(TP+FN)
    out['TNR'] = TN/(FP+TN)
    out['FPR'] = FP/(FP+TN)
    out['FNR'] = FN/(TP+FN)
    out['ACR'] = (TP+TN)/(TP+TN+FP+FN)

    return out

Male=X_test[X_test_g==1]
Female=X_test[X_test_g==0]
Male_target=y_test[X_test_g==1]
Female_target=y_test[X_test_g==0]

r1=model_eval(Male_target,np.array(model3.predict(Male)[2].squeeze()>.5,dtype=np.int32))
r2=model_eval(Female_target,np.array(model3.predict(Female)[2].squeeze()>.5,dtype=np.int32))
r3=model_eval(y_test,np.array(model3.predict(X_test)[2].squeeze()>.5,dtype=np.int32))
# Out:
# 272/272 [==============================] - 1s 3ms/step
# 136/136 [==============================] - 0s 2ms/step
# 407/407 [==============================] - 1s 2ms/step

# %%
DI = round(100 * abs(r2['DP'] - r1['DP']), 4)
DFPR = round(100 * abs(r2['TNR'] - r1['TNR']), 4)
DFNR = round(100 * abs(r2['TPR'] - r1['TPR']), 4)
prule = round(100 * min(r2['DP'] / r1['DP'], r1['DP'] / r2['DP']), 4)
ACR = round(r3['ACR']*100, 4)

print(f'Baseline method: Average accuracy is {ACR}%, Disparate impact is {DI}%, disparate TPR is {DFNR}%,\n disparate TNR is {DFPR}%, p% rule is {prule}%.')
# Out:
# Baseline method: Average accuracy is 85.473%, Disparate impact is 14.5217%, disparate TPR is 3.9948%,
#  disparate TNR is 5.4537%, p% rule is 35.8612%.
